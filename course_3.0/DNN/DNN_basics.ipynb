# %% [markdown]
# # DNN: the Basics
#
# In this notebook, we will learn the basics of a Deep Neural Network (DNN) based on [Pytorch](https://pytorch.org/), a Python based machine learning framework for building and training deep neural networks with strong GPU acceleration.
#
# We will use the `FashionMNIST` dataset, which is useful for quick examples when learning the basics. In [DNN_practical.ipynb](DNN_practical.ipynb), we will follow the same principles to practice with a more relevant scientific dataset. To understand how a DNN works, we will implement a fully connected DNN from scratch in [DNN_backprop.ipynb](DNN_backprop.ipynb),

# %%
# import Pytorch libraries
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.datasets import FashionMNIST
from torchvision.transforms import ToTensor, Compose

# check version
print('Using PyTorch v%s' % torch.__version__)

# helpers
import time
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# for reproducibility
torch.manual_seed(0)
np.random.seed(0)
# Out:
# Using PyTorch v2.2.0+cu118

# %% [markdown]
# ---

# %% [markdown]
# # The Dataset and Dataloader
#
# PyTorch has two primitives to work with data: torch.utils.data.DataLoader and torch.utils.data.Dataset. Dataset stores the samples and their corresponding labels, and DataLoader wraps an iterable around the Dataset from which samples are loaded. Dataloader supports automatic batching, sampling, shuffling and multiprocess data loading.
#
# To start with, we will use the `FashionMNIST` dataset from TorchVision. Every TorchVision Dataset includes two arguments: `transform` and `target_transform` to modify the samples and labels respectively.

# %%
# Download training data from open datasets.
training_data = FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# print info
print("Number of training samples: %d" % len(training_data))
print("Number of test samples: %d" % len(test_data))
# Out:
# Number of training samples: 60000
# Number of test samples: 10000

# %% [markdown]
# Here we define a batch size of 64, i.e. each element in the dataloader iterable will return a batch of 64 features and labels.

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# We can randomly plot some images and their labels:

# %%
string_labels = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

# function to plot an image in a subplot
def subplot_image(image, label, nrows=1, ncols=1, iplot=0, label2='', label2_color='r'):
    plt.subplot(nrows, ncols, iplot + 1)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel(label, c='k', fontsize=12)
    plt.title(label2, c=label2_color, fontsize=12, y=-0.33)
    plt.xticks([])
    plt.yticks([])
    
ncols, nrows = 3, 3
plt.figure(dpi=100, figsize=(ncols * 2, nrows * 2.2))

for iplot, idata in enumerate(np.random.choice(len(training_data), nrows * ncols)):
    img, label = training_data[iplot]
    label_str = "%d: %s" % (label, string_labels[label])
    subplot_image(img.squeeze(0), label_str, nrows, ncols, iplot)

# %% [markdown]
# ---

# %% [markdown]
# # Classification by DNN
#
# Here we will create and train a DNN model to classify the images in `FashionMNIST`. The task can be divided into three essential steps:
#
# 1. Build the neural network;
# 2. Optimize the network;
#
# These steps may be repeated for a few times to improve the quality (accuracy and stability) of the model.

# %% [markdown]
# ## 1. Build the network architecture
#
# Our first DNN will be a simple multi-layer perceptron with only one hidden layer, as shown in the following figure:
#
#
# ![dense.jpeg](https://github.com/stfc-sciml/sciml-workshop/blob/master/course_3.0_with_solutions/markdown_pic/dnn.png?raw=1)
#
# In general, a network of this kind should include an input layer, some hidden layers and an output layer. In this example, all the layers will be `Linear` layers with or without activation function. The linear layer is composed of neurons `W` and biases `b` (optional) and perform linear transformation on the input $x$, i.e. $y=xW^T+b$.
#
#
# ### The input layer
#
# We first need to determine the dimensionality of the input layer. Since we are using `Linear` layers, we will flatten the input images before feeding them to the network. As the images are 28 $\times$ 28 in pixels, the flattened input size will be 784. The flattened input will be then passed to the input layer.
#
# ### The hidden layers
#
# We use one hidden layer in this case and use `ReLU` as its activation function:
#
# > $R(x)=\max(0,x)$
#
# **NOTE**: Different activation functions are used for different tasks. Remember that `ReLU` generally performs well for training a network, but it can *only* be used in the input and hidden layers.
#
#
# ### The output layer
#
# We usually encode categorical data as a "one-hot" vector. In this case, we have a vector of length 10 on the output side, where each element corresponds to a class of apparel. Ideally, we hope the values to be either 1 or 0, with 1 for the correct class and 0 for the others, so we use `sigmoid` as the activation function for the output layer:
#
# > $S(x) = \dfrac{1}{1 + e^{-x}}$

# %%
# build a neural network in Pytorch
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim=784, hidden_dim=512, output_dim=10, dropout=0.0):
        super().__init__()

        self.hidden_dim = hidden_dim
        self.dropout = dropout
        
        self.flatten = nn.Flatten()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
        )
        self.hidden_layer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )
        self.output_layer =  nn.Sequential(
            nn.Linear(hidden_dim, output_dim),
            nn.Sigmoid()
        )

    def forward(self, x):
        y = self.flatten(x)
        y = self.input_layer(y)
        y = self.hidden_layer(y)
        y = self.output_layer(y)
        return y

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = NeuralNetwork(hidden_dim=256, dropout=0.0).to(device)
print(model)

# perform q quick check using a dummy input
inputs = torch.rand((3, 28, 28), device=device) # dummy image with batch size of 3
print('Inputs:', inputs.size())
outputs = model(inputs)
print('Outputs:', outputs.size())

y_pred = outputs.argmax(1)
print(f"Predicted class: {[string_labels[idx.item()] for idx in y_pred]}")
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (input_layer): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#   )
#   (hidden_layer): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#   )
#   (output_layer): Sequential(
#     (0): Linear(in_features=256, out_features=10, bias=True)
#     (1): Sigmoid()
#   )
# )
# Inputs: torch.Size([3, 28, 28])
# Outputs: torch.Size([3, 10])
# Predicted class: ['Sneaker', 'Sneaker', 'Sneaker']

# %% [markdown]
# To define a neural network in PyTorch, we create a class `NeuralNetwork` that inherits from Pytorch `nn.Module` which has functions implementing automatic differentiation. We define the layers of the network in the `__init__` function and specify how data will pass through the network in the `forward` function.
#
# In the above network, first, we define a flatten layer with `nn.Flatten` module to converts the 2D input image to 1D contigious array. Note that the mini batch dimension (at dim=0) will be maintained by the operation.
#
# Similarly, we define our input, hidden and output layers. Neurons in each layer is realized using the `nn.Linear` module. We use `nn.ReLU` as activation function in the input and hidden layer, whereas `nn.Sigmoid` is used in the output layer. The module `nn.Sequential` allows us to put together the list of sub-modules e.g. the `nn.Layer` and `nn.ReLU` and pass the data through the modules in the same order as defined. We also add `Dropout` layer in the `input` and `hidden` layer for network regularization.
#
# Finally, to test the model, we define a dummy input of batch size 3 and place it in the same device as the network (Pytorch require the data and network to be resided on the same device). We pass the data by calling it with the input; `model(inputs)`. This executes the model’s forward, along with some background operations.
#
# Calling the model on the input returns a 2-dimensional tensor with `dim=0` corresponding to each output of 10 raw predicted values for each class, and dim=1 corresponding to the individual values of each output. An `argmax` operation is performed along class label dimension to estimate the class label.

# %% [markdown]
# ## 2. Optimize the network
#
# To optimize the neural network, we will need a [loss function](https://pytorch.org/docs/stable/nn.html#loss-functions) and an [optimizer](https://pytorch.org/docs/stable/optim.html)
#
# ### Loss
#
# The loss is the objective function to be minimised during training. Gradients of the loss with respect to the model parameters, calculated by backpropagating the errors, determine the direction to update the model parameters. Follow [DNN_backprop.ipynb](DNN_backprop.ipynb) to learn the details about *backpropagation* and *gradient descent*. In this case, we will use `CrossEntropyLoss` as the loss function because we are dealing with 10 classes.
#
# ### Optimizer
#
# An optimiser is an algorithm determining how the model parameters are updated based on the loss. One critical hyperparameter for the optimiser is the *learning rate*, which determines the magnitude to update the model parameters (also see [DNN_backprop.ipynb](DNN_backprop.ipynb) for details). In many applications, *Adam* is usually a good choice at the beginning. We will use Adam in this example.

# %%
# define loss function
loss_fn = nn.CrossEntropyLoss()
# create a optimizer with constant learning rate of 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# To create a loss function, we will use the modules provided inside [torch.nn](https://pytorch.org/docs/stable/nn.html) and initialize an instance of `CrossEntropyLoss`. Similarly, PyTorch provides a wide range of optimizers (see [torch.optim](https://pytorch.org/docs/stable/optim.html#torch.optim.Optimizer)). We will use `Adam` optimizer for our example as it works well in most cases. The PyTorch optimizer accepts an iterable containing the parameters (all should be [Variable's](https://pytorch.org/docs/stable/generated/torch.nn.parameter.Parameter.html#torch.nn.parameter.Parameter)) to optimize and the rate at which to update the parameters.

# %% [markdown]
# ## 3. Train the Neural Network
#
# Now we can start to train the model with `FashionMNIST` dataset. Before that, we need to understand the concepts of `epochs` and `mini-batch size`.
#
# ### Epochs
#
# It is the number of times that the model will run through the entire dataset during training.
#
# ### Mini-batch size
#
# It determines how many data will be used at a time to determine the gradient used for parameter update. Follow [DNN_backprop.ipynb](DNN_backprop.ipynb) to learn more about *Batch*, *Mini-batch* and *Stochastic Gradient Descent*.

# %% [markdown]
# ### Training loop
# Unlike Keras, PyTorch doesn't have a pre-defined training loop, so we will create a simple training loop. To train the neural network, usually, we will iterate over the dataset in mini-batches, pass the mini-batches to the network, calculate the loss, compute gradients by backprogating the errors and update the weights of the neural network.

# %%
# define a train function
def train(dataloader, model, loss_fn, optimizer, device):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.train()
    
    train_loss, train_accuracy = 0, 0
    for batch, (X, y) in enumerate(dataloader):

        # place tensors to device
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred_y = model(X)

        # convert target class indices into one-hot encoding
        target_y = F.one_hot(y, 10).to(torch.float32)

        # compute loss
        loss = loss_fn(pred_y, target_y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        train_accuracy += (pred_y.argmax(1) == y).type(torch.float).sum().item()
        train_loss += loss.detach().item()
    
    train_loss /= num_batches
    train_accuracy /= size
    
    return train_loss, train_accuracy

# %% [markdown]
# ### Validation loop
#
# To assess the network's performances in new and unseen data, we will use the validation dataset at the end of training. However, the validation of the network can be done at the middle of training that helps us identify under-fitting and over-fitting problem. To make predictions with a confidence equivalent to that for training, the accuracy for the validation data should not differ too much from that for the training data.

# %%
# define a test function to evaluate the model
def test(dataloader, model, loss_fn, device):
    # set the model to eval mode
    model.eval()
    
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_accuracy = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            
            # inference/prediction
            pred_y = model(X)

            # convert target class indices into one-hot encoding
            target_y = F.one_hot(y, 10).to(torch.float32)

            # compute test loss and accuracy
            test_loss += loss_fn(pred_y, target_y).item()
            test_accuracy += (pred_y.argmax(1) == y).type(torch.float).sum().item()
            
    test_loss /= num_batches
    test_accuracy /= size

    return test_loss, test_accuracy

# %% [markdown]
# The training process is conducted over several iterations (epochs). During each epoch, entire samples is passed through the network and network's parameters are updated to make better predictions. At the end of each epoch, it is better to compute the accuracy on the test dataset to evaluate the generalizabilty of the network in unseen data. We will create a simple `trainer` function that does this function. We will also record the loss and accuracy obtained during each epoch for analysis and visualizations.

# %%
def trainer(model, train_dataloader, test_dataloader, optimizer, loss_fn, epochs, device):
    start = time.time()
    h = dict(train_loss=[], test_loss=[], train_accuracy=[], test_accuracy=[])
    for t in range(epochs):
        print(f"\nEpoch {t+1}/{epochs}: ", end='')
        
        train_loss, train_accuracy = train(train_dataloader, model, loss_fn, optimizer, device)

        test_loss, test_accuracy = test(test_dataloader, model, loss_fn, device)
        print(f"train_loss: {train_loss:0.3f}, train_accuracy: {(100*train_accuracy):0.2f}%, test_accuracy: {(100*test_accuracy):0.2f}%")

        # print(f"Test Accuracy: {(100*test_accuracy):0.2f}%, Test Loss: {test_loss:0.3f}")

        h['train_loss'].append(train_loss)
        h['test_loss'].append(test_loss)
        h['train_accuracy'].append(train_accuracy)
        h['test_accuracy'].append(test_accuracy)

    print(f"Done in {time.time()-start:.3f}secs!")
    
    return h

# plot accuracy
def plot_history(history, figsize=(12, 4)):
    plt.close('all')
    plt.figure(dpi=100, figsize=figsize)
    plt.subplot(1, 2, 1)
    plt.plot(history['train_accuracy'], label='Train')
    plt.plot(history['test_accuracy'], label='Test')
    plt.legend()
    plt.title("Accuracy")
    
    # plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history['train_loss'], label='Train')
    plt.plot(history['test_loss'], label='Test')
    plt.legend()
    plt.title("Loss")
    plt.show()

# %% [markdown]
# Let`s train the network!!

# %%
epochs = 100
history = trainer(model, train_dataloader, test_dataloader, optimizer, loss_fn, epochs, device)
# Out:
# Epoch 1/100: train_loss: 1.659, train_accuracy: 49.97%, test_accuracy: 58.89%
#
# Epoch 2/100: train_loss: 1.612, train_accuracy: 61.17%, test_accuracy: 69.34%
#
# Epoch 3/100: train_loss: 1.589, train_accuracy: 68.42%, test_accuracy: 63.55%
#
# Epoch 4/100: train_loss: 1.578, train_accuracy: 72.74%, test_accuracy: 84.04%
#
# Epoch 5/100: train_loss: 1.552, train_accuracy: 85.61%, test_accuracy: 82.85%
#
# Epoch 6/100: train_loss: 1.547, train_accuracy: 86.19%, test_accuracy: 84.63%
#
# Epoch 7/100: train_loss: 1.544, train_accuracy: 86.58%, test_accuracy: 84.98%
#
# Epoch 8/100: train_loss: 1.542, train_accuracy: 87.02%, test_accuracy: 83.98%
#
# Epoch 9/100: train_loss: 1.539, train_accuracy: 87.24%, test_accuracy: 86.13%
#
# Epoch 10/100: train_loss: 1.538, train_accuracy: 87.44%, test_accuracy: 85.12%
#
# Epoch 11/100: train_loss: 1.537, train_accuracy: 87.41%, test_accuracy: 86.07%
#
# Epoch 12/100: train_loss: 1.535, train_accuracy: 87.85%, test_accuracy: 85.85%
#
# Epoch 13/100: train_loss: 1.533, train_accuracy: 87.88%, test_accuracy: 85.99%
#
# Epoch 14/100: train_loss: 1.532, train_accuracy: 88.09%, test_accuracy: 85.90%
#
# Epoch 15/100: train_loss: 1.531, train_accuracy: 88.13%, test_accuracy: 86.48%
#
# Epoch 16/100: train_loss: 1.530, train_accuracy: 88.41%, test_accuracy: 86.52%
#
# Epoch 17/100: train_loss: 1.530, train_accuracy: 88.41%, test_accuracy: 85.74%
#
# Epoch 18/100: train_loss: 1.528, train_accuracy: 88.65%, test_accuracy: 86.17%
#
# Epoch 19/100: train_loss: 1.529, train_accuracy: 88.32%, test_accuracy: 85.60%
#
# Epoch 20/100: train_loss: 1.529, train_accuracy: 88.39%, test_accuracy: 86.55%
#
# Epoch 21/100: train_loss: 1.527, train_accuracy: 88.68%, test_accuracy: 86.81%
#
# Epoch 22/100: train_loss: 1.528, train_accuracy: 88.43%, test_accuracy: 85.77%
#
# Epoch 23/100: train_loss: 1.527, train_accuracy: 88.51%, test_accuracy: 86.84%
#
# Epoch 24/100: train_loss: 1.526, train_accuracy: 88.74%, test_accuracy: 86.46%
#
# Epoch 25/100: train_loss: 1.527, train_accuracy: 88.54%, test_accuracy: 86.95%
#
# Epoch 26/100: train_loss: 1.526, train_accuracy: 88.45%, test_accuracy: 86.32%
#
# Epoch 27/100: train_loss: 1.526, train_accuracy: 88.59%, test_accuracy: 86.49%
#
# Epoch 28/100: train_loss: 1.526, train_accuracy: 88.51%, test_accuracy: 85.74%
#
# Epoch 29/100: train_loss: 1.526, train_accuracy: 88.52%, test_accuracy: 86.62%
#
# Epoch 30/100: train_loss: 1.526, train_accuracy: 88.33%, test_accuracy: 85.35%
#
# Epoch 31/100: train_loss: 1.526, train_accuracy: 88.53%, test_accuracy: 86.77%
#
# Epoch 32/100: train_loss: 1.525, train_accuracy: 88.34%, test_accuracy: 86.98%
#
# Epoch 33/100: train_loss: 1.526, train_accuracy: 88.19%, test_accuracy: 86.19%
#
# Epoch 34/100: train_loss: 1.527, train_accuracy: 88.24%, test_accuracy: 87.00%
#
# Epoch 35/100: train_loss: 1.525, train_accuracy: 88.51%, test_accuracy: 85.36%
#
# Epoch 36/100: train_loss: 1.524, train_accuracy: 88.72%, test_accuracy: 86.57%
#
# Epoch 37/100: train_loss: 1.523, train_accuracy: 88.58%, test_accuracy: 86.72%
#
# Epoch 38/100: train_loss: 1.523, train_accuracy: 88.93%, test_accuracy: 87.08%
#
# Epoch 39/100: train_loss: 1.523, train_accuracy: 88.97%, test_accuracy: 86.22%
#
# Epoch 40/100: train_loss: 1.522, train_accuracy: 88.50%, test_accuracy: 86.08%
#
# Epoch 41/100: train_loss: 1.523, train_accuracy: 88.56%, test_accuracy: 85.28%
#
# Epoch 42/100: train_loss: 1.526, train_accuracy: 88.03%, test_accuracy: 85.06%
#
# Epoch 43/100: train_loss: 1.523, train_accuracy: 88.50%, test_accuracy: 86.53%
#
# Epoch 44/100: train_loss: 1.524, train_accuracy: 88.59%, test_accuracy: 87.08%
#
# Epoch 45/100: train_loss: 1.523, train_accuracy: 88.72%, test_accuracy: 85.71%
#
# Epoch 46/100: train_loss: 1.523, train_accuracy: 88.39%, test_accuracy: 86.49%
#
# Epoch 47/100: train_loss: 1.524, train_accuracy: 88.47%, test_accuracy: 85.02%
#
# Epoch 48/100: train_loss: 1.523, train_accuracy: 87.90%, test_accuracy: 86.34%
#
# Epoch 49/100: train_loss: 1.523, train_accuracy: 88.44%, test_accuracy: 86.20%
#
# Epoch 50/100: train_loss: 1.524, train_accuracy: 87.93%, test_accuracy: 86.42%
#
# Epoch 51/100: train_loss: 1.524, train_accuracy: 87.77%, test_accuracy: 85.04%
#
# Epoch 52/100: train_loss: 1.524, train_accuracy: 87.92%, test_accuracy: 86.13%
#
# Epoch 53/100: train_loss: 1.524, train_accuracy: 88.07%, test_accuracy: 86.64%
#
# Epoch 54/100: train_loss: 1.524, train_accuracy: 88.09%, test_accuracy: 86.47%
#
# Epoch 55/100: train_loss: 1.525, train_accuracy: 87.51%, test_accuracy: 86.39%
#
# Epoch 56/100: train_loss: 1.522, train_accuracy: 88.21%, test_accuracy: 86.81%
#
# Epoch 57/100: train_loss: 1.522, train_accuracy: 88.40%, test_accuracy: 86.30%
#
# Epoch 58/100: train_loss: 1.524, train_accuracy: 87.81%, test_accuracy: 86.67%
#
# Epoch 59/100: train_loss: 1.522, train_accuracy: 88.15%, test_accuracy: 87.42%
#
# Epoch 60/100: train_loss: 1.525, train_accuracy: 88.30%, test_accuracy: 86.33%
#
# Epoch 61/100: train_loss: 1.523, train_accuracy: 88.32%, test_accuracy: 86.57%
#
# Epoch 62/100: train_loss: 1.522, train_accuracy: 88.39%, test_accuracy: 86.05%
#
# Epoch 63/100: train_loss: 1.522, train_accuracy: 88.22%, test_accuracy: 84.57%
#
# Epoch 64/100: train_loss: 1.522, train_accuracy: 88.18%, test_accuracy: 86.14%
#
# Epoch 65/100: train_loss: 1.525, train_accuracy: 87.16%, test_accuracy: 85.23%
#
# Epoch 66/100: train_loss: 1.522, train_accuracy: 88.21%, test_accuracy: 85.33%
#
# Epoch 67/100: train_loss: 1.524, train_accuracy: 87.41%, test_accuracy: 83.87%
#
# Epoch 68/100: train_loss: 1.523, train_accuracy: 87.77%, test_accuracy: 84.32%
#
# Epoch 69/100: train_loss: 1.523, train_accuracy: 88.48%, test_accuracy: 84.42%
#
# Epoch 70/100: train_loss: 1.523, train_accuracy: 87.55%, test_accuracy: 86.44%
#
# Epoch 71/100: train_loss: 1.523, train_accuracy: 87.56%, test_accuracy: 85.70%
#
# Epoch 72/100: train_loss: 1.524, train_accuracy: 87.71%, test_accuracy: 84.70%
#
# Epoch 73/100: train_loss: 1.524, train_accuracy: 87.92%, test_accuracy: 85.09%
#
# Epoch 74/100: train_loss: 1.524, train_accuracy: 87.70%, test_accuracy: 84.36%
#
# Epoch 75/100: train_loss: 1.525, train_accuracy: 87.36%, test_accuracy: 86.29%
#
# Epoch 76/100: train_loss: 1.523, train_accuracy: 88.18%, test_accuracy: 85.46%
#
# Epoch 77/100: train_loss: 1.527, train_accuracy: 87.22%, test_accuracy: 86.40%
#
# Epoch 78/100: train_loss: 1.525, train_accuracy: 87.70%, test_accuracy: 83.61%
#
# Epoch 79/100: train_loss: 1.527, train_accuracy: 86.58%, test_accuracy: 85.94%
#
# Epoch 80/100: train_loss: 1.525, train_accuracy: 87.34%, test_accuracy: 86.15%
#
# Epoch 81/100: train_loss: 1.523, train_accuracy: 87.35%, test_accuracy: 86.42%
#
# Epoch 82/100: train_loss: 1.524, train_accuracy: 87.56%, test_accuracy: 85.76%
#
# Epoch 83/100: train_loss: 1.525, train_accuracy: 87.44%, test_accuracy: 85.54%
#
# Epoch 84/100: train_loss: 1.525, train_accuracy: 87.48%, test_accuracy: 83.56%
#
# Epoch 85/100: train_loss: 1.522, train_accuracy: 87.16%, test_accuracy: 86.04%
#
# Epoch 86/100: train_loss: 1.527, train_accuracy: 86.41%, test_accuracy: 85.40%
#
# Epoch 87/100: train_loss: 1.528, train_accuracy: 86.56%, test_accuracy: 82.59%
#
# Epoch 88/100: train_loss: 1.526, train_accuracy: 87.27%, test_accuracy: 84.14%
#
# Epoch 89/100: train_loss: 1.526, train_accuracy: 87.20%, test_accuracy: 85.82%
#
# Epoch 90/100: train_loss: 1.526, train_accuracy: 87.20%, test_accuracy: 84.35%
#
# Epoch 91/100: train_loss: 1.528, train_accuracy: 86.86%, test_accuracy: 85.65%
#
# Epoch 92/100: train_loss: 1.527, train_accuracy: 86.81%, test_accuracy: 85.90%
#
# Epoch 93/100: train_loss: 1.528, train_accuracy: 85.25%, test_accuracy: 85.30%
#
# Epoch 94/100: train_loss: 1.527, train_accuracy: 86.63%, test_accuracy: 82.25%
#
# Epoch 95/100: train_loss: 1.528, train_accuracy: 86.92%, test_accuracy: 85.63%
#
# Epoch 96/100: train_loss: 1.528, train_accuracy: 86.83%, test_accuracy: 83.71%
#
# Epoch 97/100: train_loss: 1.530, train_accuracy: 85.96%, test_accuracy: 84.75%
#
# Epoch 98/100: train_loss: 1.529, train_accuracy: 86.13%, test_accuracy: 85.41%
#
# Epoch 99/100: train_loss: 1.531, train_accuracy: 85.11%, test_accuracy: 81.88%
#
# Epoch 100/100: train_loss: 1.528, train_accuracy: 86.04%, test_accuracy: 83.63%
# Done in 696.538secs!

# %% [markdown]
# ### Check training history
#
# We can examine the training history by plotting accuracy and loss against epoch for both the training and the test data.
#
# Notice that the accuracies for the training and the test data diverge as the model trains (after around epoch 50). This is a classic symptom of [overfitting](https://en.wikipedia.org/wiki/Overfitting), that is, our model corresponds too closely to the training data so that it cannot fit the test data with an equivalent accuracy.

# %%
plot_history(history)

# %% [markdown]
# ### Finding the best epoch for early-stopping
# The test accuracy at the end of the training may not always represent the optimal value because the network can reach the peak accuracy even before the final epoch. It is good idea to identify such point and stop the training because training beyond this point doesn't improve the test accuracy. This strategy is also known as early-stopping and is widely used to minimize the training time.

# %%
print(f"Best train accuracy: {np.max(history['train_accuracy']):0.2f} at epoch {np.argmax(history['train_accuracy'])}")
print(f"Best test accuracy: {np.max(history['test_accuracy']):0.2f} at epoch {np.argmax(history['test_accuracy'])}")
# Out:
# Best train accuracy: 0.89 at epoch 38
# Best test accuracy: 0.87 at epoch 58

# %% [markdown]
# ### Hyperparameter Tunning
#
# There are several factors affecting the prediction accuracy e.g. model complexity, learning rate, batch size and so on. We will need to address each factor step-by-step. For instance, we can decrease the model complexity by reducing the `hidden_dim` by half and re-run the experiment.

# %%
model = NeuralNetwork(hidden_dim=128).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
history =  trainer(model, train_dataloader, test_dataloader, optimizer, loss_fn, epochs)
plot_history(history)
# Out:
# Epoch 1/100: train_loss: 1.669, train_accuracy: 47.38%, test_accuracy: 49.85%
#
# Epoch 2/100: train_loss: 1.621, train_accuracy: 54.07%, test_accuracy: 61.78%
#
# Epoch 3/100: train_loss: 1.598, train_accuracy: 65.29%, test_accuracy: 66.70%
#
# Epoch 4/100: train_loss: 1.582, train_accuracy: 69.27%, test_accuracy: 66.89%
#
# Epoch 5/100: train_loss: 1.573, train_accuracy: 75.60%, test_accuracy: 83.14%
#
# Epoch 6/100: train_loss: 1.550, train_accuracy: 85.88%, test_accuracy: 85.24%
#
# Epoch 7/100: train_loss: 1.544, train_accuracy: 86.51%, test_accuracy: 85.32%
#
# Epoch 8/100: train_loss: 1.542, train_accuracy: 86.72%, test_accuracy: 85.19%
#
# Epoch 9/100: train_loss: 1.539, train_accuracy: 87.22%, test_accuracy: 84.96%
#
# Epoch 10/100: train_loss: 1.538, train_accuracy: 87.42%, test_accuracy: 85.44%
#
# Epoch 11/100: train_loss: 1.536, train_accuracy: 87.53%, test_accuracy: 85.27%
#
# Epoch 12/100: train_loss: 1.534, train_accuracy: 87.88%, test_accuracy: 85.99%
#
# Epoch 13/100: train_loss: 1.532, train_accuracy: 88.06%, test_accuracy: 86.19%
#
# Epoch 14/100: train_loss: 1.531, train_accuracy: 88.11%, test_accuracy: 85.89%
#
# Epoch 15/100: train_loss: 1.530, train_accuracy: 88.30%, test_accuracy: 86.07%
#
# Epoch 16/100: train_loss: 1.530, train_accuracy: 88.34%, test_accuracy: 86.92%
#
# Epoch 17/100: train_loss: 1.528, train_accuracy: 88.63%, test_accuracy: 86.21%
#
# Epoch 18/100: train_loss: 1.528, train_accuracy: 88.62%, test_accuracy: 86.46%
#
# Epoch 19/100: train_loss: 1.527, train_accuracy: 88.72%, test_accuracy: 86.69%
#
# Epoch 20/100: train_loss: 1.526, train_accuracy: 89.00%, test_accuracy: 86.30%
#
# Epoch 21/100: train_loss: 1.525, train_accuracy: 88.96%, test_accuracy: 86.77%
#
# Epoch 22/100: train_loss: 1.525, train_accuracy: 88.98%, test_accuracy: 86.58%
#
# Epoch 23/100: train_loss: 1.524, train_accuracy: 89.16%, test_accuracy: 86.48%
#
# Epoch 24/100: train_loss: 1.524, train_accuracy: 89.09%, test_accuracy: 87.40%
#
# Epoch 25/100: train_loss: 1.523, train_accuracy: 89.22%, test_accuracy: 87.38%
#
# Epoch 26/100: train_loss: 1.521, train_accuracy: 89.47%, test_accuracy: 86.33%
#
# Epoch 27/100: train_loss: 1.521, train_accuracy: 89.47%, test_accuracy: 87.02%
#
# Epoch 28/100: train_loss: 1.521, train_accuracy: 89.44%, test_accuracy: 87.31%
#
# Epoch 29/100: train_loss: 1.519, train_accuracy: 89.57%, test_accuracy: 87.14%
#
# Epoch 30/100: train_loss: 1.520, train_accuracy: 89.50%, test_accuracy: 87.20%
#
# Epoch 31/100: train_loss: 1.520, train_accuracy: 89.50%, test_accuracy: 87.06%
#
# Epoch 32/100: train_loss: 1.519, train_accuracy: 89.69%, test_accuracy: 87.46%
#
# Epoch 33/100: train_loss: 1.520, train_accuracy: 89.66%, test_accuracy: 87.14%
#
# Epoch 34/100: train_loss: 1.519, train_accuracy: 89.65%, test_accuracy: 86.89%
#
# Epoch 35/100: train_loss: 1.520, train_accuracy: 89.46%, test_accuracy: 86.98%
#
# Epoch 36/100: train_loss: 1.519, train_accuracy: 89.59%, test_accuracy: 87.29%
#
# Epoch 37/100: train_loss: 1.518, train_accuracy: 89.90%, test_accuracy: 86.97%
#
# Epoch 38/100: train_loss: 1.517, train_accuracy: 89.81%, test_accuracy: 87.53%
#
# Epoch 39/100: train_loss: 1.517, train_accuracy: 90.00%, test_accuracy: 86.84%
#
# Epoch 40/100: train_loss: 1.518, train_accuracy: 89.75%, test_accuracy: 87.32%
#
# Epoch 41/100: train_loss: 1.518, train_accuracy: 89.66%, test_accuracy: 87.27%
#
# Epoch 42/100: train_loss: 1.516, train_accuracy: 90.07%, test_accuracy: 86.89%
#
# Epoch 43/100: train_loss: 1.516, train_accuracy: 90.06%, test_accuracy: 87.30%
#
# Epoch 44/100: train_loss: 1.516, train_accuracy: 90.19%, test_accuracy: 87.42%
#
# Epoch 45/100: train_loss: 1.516, train_accuracy: 89.97%, test_accuracy: 87.10%
#
# Epoch 46/100: train_loss: 1.516, train_accuracy: 90.13%, test_accuracy: 87.85%
#
# Epoch 47/100: train_loss: 1.515, train_accuracy: 90.17%, test_accuracy: 86.95%
#
# Epoch 48/100: train_loss: 1.515, train_accuracy: 90.20%, test_accuracy: 86.26%
#
# Epoch 49/100: train_loss: 1.515, train_accuracy: 89.97%, test_accuracy: 86.92%
#
# Epoch 50/100: train_loss: 1.516, train_accuracy: 89.87%, test_accuracy: 86.53%
#
# Epoch 51/100: train_loss: 1.515, train_accuracy: 90.12%, test_accuracy: 87.05%
#
# Epoch 52/100: train_loss: 1.514, train_accuracy: 90.20%, test_accuracy: 86.51%
#
# Epoch 53/100: train_loss: 1.514, train_accuracy: 90.18%, test_accuracy: 86.90%
#
# Epoch 54/100: train_loss: 1.514, train_accuracy: 90.18%, test_accuracy: 87.12%
#
# Epoch 55/100: train_loss: 1.515, train_accuracy: 90.23%, test_accuracy: 86.88%
#
# Epoch 56/100: train_loss: 1.514, train_accuracy: 90.13%, test_accuracy: 87.79%
#
# Epoch 57/100: train_loss: 1.515, train_accuracy: 90.08%, test_accuracy: 87.80%
#
# Epoch 58/100: train_loss: 1.514, train_accuracy: 90.28%, test_accuracy: 87.31%
#
# Epoch 59/100: train_loss: 1.514, train_accuracy: 90.38%, test_accuracy: 86.44%
#
# Epoch 60/100: train_loss: 1.515, train_accuracy: 90.07%, test_accuracy: 86.85%
#
# Epoch 61/100: train_loss: 1.515, train_accuracy: 89.91%, test_accuracy: 87.52%
#
# Epoch 62/100: train_loss: 1.514, train_accuracy: 90.06%, test_accuracy: 87.29%
#
# Epoch 63/100: train_loss: 1.514, train_accuracy: 90.32%, test_accuracy: 85.93%
#
# Epoch 64/100: train_loss: 1.515, train_accuracy: 90.01%, test_accuracy: 86.46%
#
# Epoch 65/100: train_loss: 1.513, train_accuracy: 90.43%, test_accuracy: 87.34%
#
# Epoch 66/100: train_loss: 1.512, train_accuracy: 90.38%, test_accuracy: 87.79%
#
# Epoch 67/100: train_loss: 1.514, train_accuracy: 90.25%, test_accuracy: 87.67%
#
# Epoch 68/100: train_loss: 1.512, train_accuracy: 90.61%, test_accuracy: 86.90%
#
# Epoch 69/100: train_loss: 1.513, train_accuracy: 90.16%, test_accuracy: 87.70%
#
# Epoch 70/100: train_loss: 1.512, train_accuracy: 90.50%, test_accuracy: 87.35%
#
# Epoch 71/100: train_loss: 1.512, train_accuracy: 90.43%, test_accuracy: 87.44%
#
# Epoch 72/100: train_loss: 1.512, train_accuracy: 90.59%, test_accuracy: 87.86%
#
# Epoch 73/100: train_loss: 1.513, train_accuracy: 90.49%, test_accuracy: 86.65%
#
# Epoch 74/100: train_loss: 1.512, train_accuracy: 90.14%, test_accuracy: 86.57%
#
# Epoch 75/100: train_loss: 1.513, train_accuracy: 90.37%, test_accuracy: 87.42%
#
# Epoch 76/100: train_loss: 1.512, train_accuracy: 90.33%, test_accuracy: 87.44%
#
# Epoch 77/100: train_loss: 1.513, train_accuracy: 90.21%, test_accuracy: 87.63%
#
# Epoch 78/100: train_loss: 1.513, train_accuracy: 90.34%, test_accuracy: 87.38%
#
# Epoch 79/100: train_loss: 1.513, train_accuracy: 90.37%, test_accuracy: 85.93%
#
# Epoch 80/100: train_loss: 1.512, train_accuracy: 90.34%, test_accuracy: 85.80%
#
# Epoch 81/100: train_loss: 1.513, train_accuracy: 89.83%, test_accuracy: 85.67%
#
# Epoch 82/100: train_loss: 1.512, train_accuracy: 90.27%, test_accuracy: 87.17%
#
# Epoch 83/100: train_loss: 1.511, train_accuracy: 90.42%, test_accuracy: 86.16%
#
# Epoch 84/100: train_loss: 1.513, train_accuracy: 89.89%, test_accuracy: 87.12%
#
# Epoch 85/100: train_loss: 1.513, train_accuracy: 90.20%, test_accuracy: 86.91%
#
# Epoch 86/100: train_loss: 1.512, train_accuracy: 90.07%, test_accuracy: 87.02%
#
# Epoch 87/100: train_loss: 1.512, train_accuracy: 90.29%, test_accuracy: 87.15%
#
# Epoch 88/100: train_loss: 1.511, train_accuracy: 90.65%, test_accuracy: 87.45%
#
# Epoch 89/100: train_loss: 1.512, train_accuracy: 90.29%, test_accuracy: 86.39%
#
# Epoch 90/100: train_loss: 1.512, train_accuracy: 90.52%, test_accuracy: 86.25%
#
# Epoch 91/100: train_loss: 1.512, train_accuracy: 90.36%, test_accuracy: 87.54%
#
# Epoch 92/100: train_loss: 1.512, train_accuracy: 90.37%, test_accuracy: 86.89%
#
# Epoch 93/100: train_loss: 1.511, train_accuracy: 90.23%, test_accuracy: 86.93%
#
# Epoch 94/100: train_loss: 1.511, train_accuracy: 90.12%, test_accuracy: 86.77%
#
# Epoch 95/100: train_loss: 1.512, train_accuracy: 90.15%, test_accuracy: 86.19%
#
# Epoch 96/100: train_loss: 1.511, train_accuracy: 90.06%, test_accuracy: 86.11%
#
# Epoch 97/100: train_loss: 1.512, train_accuracy: 89.82%, test_accuracy: 87.34%
#
# Epoch 98/100: train_loss: 1.512, train_accuracy: 89.99%, test_accuracy: 86.03%
#
# Epoch 99/100: train_loss: 1.513, train_accuracy: 89.77%, test_accuracy: 85.15%
#
# Epoch 100/100: train_loss: 1.510, train_accuracy: 90.25%, test_accuracy: 87.19%
# Done in 698.525secs!

# %% [markdown]
# ## 4. Regularisation
#
# Regularisation of the network helps to mitigate the overfitting and gradient exploding problem. Dropout, also called dilution, is a popular regularisation technique which randomly omit a certain amount of neurons from a layer with probability `p`. Here we will rebuild our model with `Dropout` layer between the hidden and the output layers. Let us see whether this can negate the overfitting or not.

# %%
batch_size = 256
# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

model = NeuralNetwork(hidden_dim=128, dropout=0.2).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)
history =  trainer(model, train_dataloader, test_dataloader, optimizer, loss_fn, epochs)
# Out:
# Epoch 1/100: train_loss: 1.697, train_accuracy: 45.87%, test_accuracy: 47.54%
#
# Epoch 2/100: train_loss: 1.631, train_accuracy: 51.32%, test_accuracy: 54.36%
#
# Epoch 3/100: train_loss: 1.614, train_accuracy: 59.64%, test_accuracy: 63.80%
#
# Epoch 4/100: train_loss: 1.589, train_accuracy: 66.17%, test_accuracy: 65.05%
#
# Epoch 5/100: train_loss: 1.582, train_accuracy: 67.04%, test_accuracy: 66.18%
#
# Epoch 6/100: train_loss: 1.578, train_accuracy: 67.80%, test_accuracy: 66.53%
#
# Epoch 7/100: train_loss: 1.575, train_accuracy: 68.46%, test_accuracy: 67.52%
#
# Epoch 8/100: train_loss: 1.570, train_accuracy: 70.09%, test_accuracy: 69.81%
#
# Epoch 9/100: train_loss: 1.567, train_accuracy: 73.39%, test_accuracy: 85.05%
#
# Epoch 10/100: train_loss: 1.545, train_accuracy: 87.01%, test_accuracy: 85.38%
#
# Epoch 11/100: train_loss: 1.541, train_accuracy: 87.45%, test_accuracy: 85.90%
#
# Epoch 12/100: train_loss: 1.540, train_accuracy: 87.67%, test_accuracy: 85.65%
#
# Epoch 13/100: train_loss: 1.538, train_accuracy: 87.77%, test_accuracy: 85.61%
#
# Epoch 14/100: train_loss: 1.537, train_accuracy: 87.90%, test_accuracy: 86.80%
#
# Epoch 15/100: train_loss: 1.534, train_accuracy: 88.23%, test_accuracy: 86.39%
#
# Epoch 16/100: train_loss: 1.532, train_accuracy: 88.48%, test_accuracy: 87.17%
#
# Epoch 17/100: train_loss: 1.532, train_accuracy: 88.43%, test_accuracy: 86.07%
#
# Epoch 18/100: train_loss: 1.531, train_accuracy: 88.59%, test_accuracy: 87.06%
#
# Epoch 19/100: train_loss: 1.529, train_accuracy: 88.63%, test_accuracy: 86.82%
#
# Epoch 20/100: train_loss: 1.529, train_accuracy: 88.83%, test_accuracy: 86.76%
#
# Epoch 21/100: train_loss: 1.527, train_accuracy: 88.98%, test_accuracy: 87.17%
#
# Epoch 22/100: train_loss: 1.527, train_accuracy: 88.98%, test_accuracy: 87.14%
#
# Epoch 23/100: train_loss: 1.526, train_accuracy: 88.98%, test_accuracy: 87.42%
#
# Epoch 24/100: train_loss: 1.527, train_accuracy: 88.99%, test_accuracy: 86.98%
#
# Epoch 25/100: train_loss: 1.526, train_accuracy: 89.02%, test_accuracy: 86.87%
#
# Epoch 26/100: train_loss: 1.525, train_accuracy: 89.18%, test_accuracy: 86.85%
#
# Epoch 27/100: train_loss: 1.523, train_accuracy: 89.42%, test_accuracy: 86.95%
#
# Epoch 28/100: train_loss: 1.523, train_accuracy: 89.21%, test_accuracy: 87.37%
#
# Epoch 29/100: train_loss: 1.523, train_accuracy: 89.34%, test_accuracy: 86.92%
#
# Epoch 30/100: train_loss: 1.523, train_accuracy: 89.28%, test_accuracy: 87.07%
#
# Epoch 31/100: train_loss: 1.521, train_accuracy: 89.79%, test_accuracy: 87.49%
#
# Epoch 32/100: train_loss: 1.521, train_accuracy: 89.50%, test_accuracy: 86.18%
#
# Epoch 33/100: train_loss: 1.522, train_accuracy: 89.44%, test_accuracy: 86.67%
#
# Epoch 34/100: train_loss: 1.522, train_accuracy: 89.55%, test_accuracy: 87.10%
#
# Epoch 35/100: train_loss: 1.521, train_accuracy: 89.72%, test_accuracy: 86.98%
#
# Epoch 36/100: train_loss: 1.521, train_accuracy: 89.78%, test_accuracy: 87.46%
#
# Epoch 37/100: train_loss: 1.520, train_accuracy: 89.42%, test_accuracy: 86.82%
#
# Epoch 38/100: train_loss: 1.520, train_accuracy: 89.67%, test_accuracy: 86.94%
#
# Epoch 39/100: train_loss: 1.520, train_accuracy: 89.55%, test_accuracy: 87.16%
#
# Epoch 40/100: train_loss: 1.519, train_accuracy: 89.82%, test_accuracy: 86.94%
#
# Epoch 41/100: train_loss: 1.519, train_accuracy: 89.82%, test_accuracy: 87.86%
#
# Epoch 42/100: train_loss: 1.519, train_accuracy: 89.81%, test_accuracy: 87.06%
#
# Epoch 43/100: train_loss: 1.519, train_accuracy: 89.81%, test_accuracy: 86.95%
#
# Epoch 44/100: train_loss: 1.517, train_accuracy: 90.06%, test_accuracy: 87.21%
#
# Epoch 45/100: train_loss: 1.518, train_accuracy: 90.03%, test_accuracy: 87.89%
#
# Epoch 46/100: train_loss: 1.518, train_accuracy: 90.00%, test_accuracy: 86.81%
#
# Epoch 47/100: train_loss: 1.519, train_accuracy: 89.78%, test_accuracy: 87.13%
#
# Epoch 48/100: train_loss: 1.516, train_accuracy: 90.08%, test_accuracy: 87.47%
#
# Epoch 49/100: train_loss: 1.516, train_accuracy: 90.09%, test_accuracy: 87.56%
#
# Epoch 50/100: train_loss: 1.517, train_accuracy: 89.93%, test_accuracy: 87.86%
#
# Epoch 51/100: train_loss: 1.516, train_accuracy: 90.06%, test_accuracy: 87.10%
#
# Epoch 52/100: train_loss: 1.517, train_accuracy: 89.95%, test_accuracy: 86.64%
#
# Epoch 53/100: train_loss: 1.517, train_accuracy: 89.93%, test_accuracy: 87.53%
#
# Epoch 54/100: train_loss: 1.517, train_accuracy: 89.89%, test_accuracy: 87.21%
#
# Epoch 55/100: train_loss: 1.515, train_accuracy: 90.16%, test_accuracy: 87.71%
#
# Epoch 56/100: train_loss: 1.515, train_accuracy: 90.14%, test_accuracy: 87.18%
#
# Epoch 57/100: train_loss: 1.516, train_accuracy: 90.01%, test_accuracy: 86.60%
#
# Epoch 58/100: train_loss: 1.516, train_accuracy: 90.04%, test_accuracy: 87.38%
#
# Epoch 59/100: train_loss: 1.516, train_accuracy: 89.99%, test_accuracy: 87.48%
#
# Epoch 60/100: train_loss: 1.514, train_accuracy: 90.38%, test_accuracy: 87.22%
#
# Epoch 61/100: train_loss: 1.515, train_accuracy: 90.07%, test_accuracy: 87.63%
#
# Epoch 62/100: train_loss: 1.514, train_accuracy: 90.10%, test_accuracy: 87.00%
#
# Epoch 63/100: train_loss: 1.516, train_accuracy: 90.11%, test_accuracy: 87.23%
#
# Epoch 64/100: train_loss: 1.514, train_accuracy: 90.40%, test_accuracy: 87.75%
#
# Epoch 65/100: train_loss: 1.514, train_accuracy: 90.30%, test_accuracy: 87.16%
#
# Epoch 66/100: train_loss: 1.514, train_accuracy: 90.34%, test_accuracy: 86.64%
#
# Epoch 67/100: train_loss: 1.514, train_accuracy: 90.32%, test_accuracy: 88.12%
#
# Epoch 68/100: train_loss: 1.513, train_accuracy: 90.45%, test_accuracy: 87.38%
#
# Epoch 69/100: train_loss: 1.514, train_accuracy: 90.20%, test_accuracy: 87.64%
#
# Epoch 70/100: train_loss: 1.514, train_accuracy: 90.13%, test_accuracy: 87.28%
#
# Epoch 71/100: train_loss: 1.514, train_accuracy: 90.03%, test_accuracy: 87.31%
#
# Epoch 72/100: train_loss: 1.514, train_accuracy: 90.34%, test_accuracy: 87.26%
#
# Epoch 73/100: train_loss: 1.513, train_accuracy: 90.51%, test_accuracy: 87.62%
#
# Epoch 74/100: train_loss: 1.513, train_accuracy: 90.33%, test_accuracy: 86.83%
#
# Epoch 75/100: train_loss: 1.514, train_accuracy: 90.21%, test_accuracy: 86.62%
#
# Epoch 76/100: train_loss: 1.513, train_accuracy: 90.56%, test_accuracy: 87.87%
#
# Epoch 77/100: train_loss: 1.512, train_accuracy: 90.53%, test_accuracy: 87.19%
#
# Epoch 78/100: train_loss: 1.513, train_accuracy: 90.29%, test_accuracy: 87.13%
#
# Epoch 79/100: train_loss: 1.513, train_accuracy: 90.34%, test_accuracy: 88.04%
#
# Epoch 80/100: train_loss: 1.514, train_accuracy: 90.44%, test_accuracy: 86.18%
#
# Epoch 81/100: train_loss: 1.513, train_accuracy: 90.63%, test_accuracy: 87.50%
#
# Epoch 82/100: train_loss: 1.513, train_accuracy: 90.58%, test_accuracy: 87.56%
#
# Epoch 83/100: train_loss: 1.513, train_accuracy: 90.56%, test_accuracy: 87.50%
#
# Epoch 84/100: train_loss: 1.514, train_accuracy: 90.27%, test_accuracy: 87.61%
#
# Epoch 85/100: train_loss: 1.514, train_accuracy: 90.18%, test_accuracy: 87.02%
#
# Epoch 86/100: train_loss: 1.512, train_accuracy: 90.50%, test_accuracy: 87.30%
#
# Epoch 87/100: train_loss: 1.514, train_accuracy: 90.29%, test_accuracy: 86.35%
#
# Epoch 88/100: train_loss: 1.513, train_accuracy: 90.34%, test_accuracy: 87.89%
#
# Epoch 89/100: train_loss: 1.512, train_accuracy: 90.33%, test_accuracy: 87.71%
#
# Epoch 90/100: train_loss: 1.513, train_accuracy: 90.46%, test_accuracy: 87.23%
#
# Epoch 91/100: train_loss: 1.512, train_accuracy: 90.40%, test_accuracy: 86.65%
#
# Epoch 92/100: train_loss: 1.510, train_accuracy: 90.80%, test_accuracy: 87.12%
#
# Epoch 93/100: train_loss: 1.512, train_accuracy: 90.61%, test_accuracy: 86.94%
#
# Epoch 94/100: train_loss: 1.512, train_accuracy: 90.51%, test_accuracy: 87.69%
#
# Epoch 95/100: train_loss: 1.511, train_accuracy: 90.66%, test_accuracy: 87.76%
#
# Epoch 96/100: train_loss: 1.510, train_accuracy: 90.83%, test_accuracy: 87.08%
#
# Epoch 97/100: train_loss: 1.511, train_accuracy: 90.89%, test_accuracy: 87.29%
#
# Epoch 98/100: train_loss: 1.513, train_accuracy: 90.50%, test_accuracy: 88.22%
#
# Epoch 99/100: train_loss: 1.512, train_accuracy: 90.61%, test_accuracy: 86.98%
#
# Epoch 100/100: train_loss: 1.513, train_accuracy: 90.44%, test_accuracy: 87.67%
# Done in 576.763secs!

# %%
plot_history(history)
print(f"Best train accuracy: {np.max(history['train_accuracy']):0.2f}")
print(f"Best test accuracy: {np.max(history['test_accuracy']):0.2f}")
# Out:
# Best train accuracy: 0.91
# Best test accuracy: 0.88

# %% [markdown]
# ## 5. Make predictions/inference
#
# Finally, we can use our trained model to make predictions. Here we show some wrong predictions for the test data, from which we may get some ideas about what kinds of images baffle our model.

# %%
# use test images to make predictions
def predict(dataloader, model):
    # set the model to eval mode
    model.eval()
    
    gt_images, gt_labels, pred_labels = [], [], []
    
    with torch.no_grad():
        for X, y in dataloader:
            
            # inference/prediction
            pred_y = model(X.to(device)).cpu().numpy()

            gt_images.append(X.numpy())
            gt_labels.append(y.numpy())
            pred_labels.append(pred_y.argmax(1))

    gt_images = np.concatenate(gt_images)
    gt_labels = np.concatenate(gt_labels)
    pred_labels = np.concatenate(pred_labels)
    
    return gt_images, gt_labels, pred_labels

# %%
test_dataloader = DataLoader(test_data, batch_size=1024)

test_images, test_labels, pred_labels = predict(test_dataloader, model)

# convert to numpy
test_images = test_images.cpu().numpy()
pred_labels = pred_labels.cpu().numpy()
test_labels = test_labels.cpu().numpy()

# get the indices of wrong predictions
id_wrong = np.where(pred_labels != test_labels)[0]
print("Number of test data: %d" % test_labels.size)
print("Number of wrong predictions: %d" % id_wrong.size)

# plot the wrong predictions
nrows = 4
ncols = 8
plt.figure(dpi=100, figsize=(ncols * 2, nrows * 2.2))
for iplot, idata in enumerate(np.random.choice(id_wrong, nrows * ncols)):
    label = "%d: %s" % (test_labels[idata], string_labels[test_labels[idata]])
    label2 = "%d: %s" % (pred_labels[idata], string_labels[pred_labels[idata]])
    subplot_image(test_images[idata].squeeze(), label, nrows, ncols, iplot, label2, 'r')
plt.show()
# Out:
# Number of test data: 10000
# Number of wrong predictions: 1233

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises
#
# * Change some hyperparameters like `hidden_dim`, `dropout` in the `NeuralNetwork` to see their effects.
# * Use two hidden layers respectively with sizes 256 and 64, and see whether the accuracy can be improved or not;
# * Change the output from 0-1 binary to probability, i.e., the one-hot vector represents the probabilities that an image belongs to the classes; this can be achieved by 1) replacing the `nn.Sigmoid()` in the output layer with a `nn.Softmax()`.
# * Double the batch size and learning rate
# * Change the optimizer to `AdamW` (see other [optmizers](https://pytorch.org/docs/stable/optim.html)) with or without weight regularization
